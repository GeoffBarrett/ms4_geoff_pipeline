# %%
from p_ms4_geoff import sort_dataset
import os
import numpy as np

# %%
def find_sub(string, sub):
    '''finds all instances of a substring within a string and outputs a list of indices'''
    result = []
    k = 0
    while k < len(string):
        k = string.find(sub, k)
        if k == -1:
            return result
        else:
            result.append(k)
            k += 1  # change to k += len(sub) to not search overlapping results
    return result


def get_ubuntu_path(filepath):
    # get the drive letter

    drive_letter_i = filepath.find(':/')

    if drive_letter_i == -1:
        drive_letter_i = filepath.find(':\\')

    drive_letter = filepath[:drive_letter_i].lower()

    i = 1
    while drive_letter_i + i == '/':
        i += 1

    remaining_path = filepath[drive_letter_i + i + 1:]
    linux_path = '/mnt/%s/%s' % (drive_letter, remaining_path)
    
    # add single quotes so linux can understand the special characters
    if '(' in linux_path or ')' in linux_path:
        linux_path = "'%s'" % linux_path

    return os.path.normpath((linux_path)).replace('\\', '/')

# %% [markdown]
# ### Note I use get_ubuntu_path because I use the Windows Subsystem for Linux so I convert my windows paths to what they get mapped to in Linux. If you are on a Linux machine you can skip the get_ubunut_path parts.

# %%
# raw_fname = 'E://Apollo_D_Drive//04032018//b6_march_18_1_180403_150327_T4_raw.mda'
raw_fname = 'E:\\Apollo_D_Drive\\b6_august_18_2\\b6_august_18_2_simple_circle_180830_134604_T1_raw.mda'

mda_basename = os.path.splitext(raw_fname)[0]
mda_basename = mda_basename[:find_sub(mda_basename, '_')[-1]]

firings_out = get_ubuntu_path(mda_basename + '_firings.mda')
filt_out_fname = get_ubuntu_path(mda_basename + '_filt.mda')
pre_out_fname = get_ubuntu_path(mda_basename + '_pre.mda')
metrics_out_fname = get_ubuntu_path(mda_basename + '_metrics.json')

raw_fname = get_ubuntu_path(raw_fname)

# %%
'''raw_fname=None, pre_fname=None, geom_fname=None, params_fname=None,
                 firings_out, filt_out_fname, pre_out_fname, metrics_out_fname,
                 freq_min=300, freq_max=7000, samplerate=30000, detect_sign=1,
                 adjacency_radius=-1, detect_threshold=3, detect_interval=50, clip_size=50,
                 firing_rate_thresh=0.05, isolation_thresh=0.95, noise_overlap_thresh=0.03,
                 peak_snr_thresh=1.5'''
# Out:
# 'raw_fname=None, pre_fname=None, geom_fname=None, params_fname=None,\n                 firings_out, filt_out_fname, pre_out_fname, metrics_out_fname,\n                 freq_min=300, freq_max=7000, samplerate=30000, detect_sign=1,\n                 adjacency_radius=-1, detect_threshold=3, detect_interval=50, clip_size=50,\n                 firing_rate_thresh=0.05, isolation_thresh=0.95, noise_overlap_thresh=0.03,\n                 peak_snr_thresh=1.5'

# %%
samplerate=int(48e3)
detect_interval=10
detect_sign=1
detect_threshold=3
freq_min=300
freq_max=7000

# %%
sort_dataset(raw_fname=raw_fname, filt_out_fname=filt_out_fname, pre_out_fname=pre_out_fname, 
             metrics_out_fname=metrics_out_fname, firings_out=firings_out, 
             samplerate=samplerate, detect_interval=detect_interval, detect_sign=detect_sign, 
             detect_threshold=detect_threshold, freq_min=freq_min, freq_max=freq_max
            )
# Out:
# RUNNING: ml-run-process ephys.bandpass_filter --inputs timeseries:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_raw.mda --parameters freq_max:7000 freq_min:300 samplerate:48000 --outputs timeseries_out:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_filt.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.bandpass_filter --timeseries=/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_raw.mda --timeseries_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_60cc93b345_D1jIJu/output_timeseries_out.mda --freq_max=7000 --freq_min=300 --samplerate=48000 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_60cc93b345_D1jIJu
# Chunk size: 30000, Padding: 3000, Num chunks: 1869, Num processes: 12
#
# Processed 1377 of 1869 chunks...
#
# Processed 646 of 1869 chunks...
# Processed 1739 of 1869 chunks...
#
# Processed 1012 of 1869 chunks...
#
# Processed 294 of 1869 chunks...
#
# Elapsed time for processor ephys.bandpass_filter: 21.91 sec
# Finalizing output timeseries_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ephys.whiten --inputs timeseries:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_filt.mda --parameters --outputs timeseries_out:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_pre.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.whiten --timeseries=/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_filt.mda --timeseries_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_d4c2c1a0b6_5nTRZZ/output_timeseries_out.mda --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_d4c2c1a0b6_5nTRZZ
# Chunk size: 300000, Num chunks: 187, Num processes: 12
#
# Processed 84 of 187 chunks...
#
# Processed 162 of 187 chunks...
#
# Elapsed time for processor ephys.whiten: 10.323 sec
# Finalizing output timeseries_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.sort --inputs timeseries:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_pre.mda --parameters adjacency_radius:-1 clip_size:50 detect_sign:1 detect_threshold:3 --outputs firings_out:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_firings.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ms4alg/ms4alg_spec.py.mp ms4alg.sort --timeseries=/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_pre.mda --geom= --firings_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_907b89b3dd_rgoVH1/output_firings_out.mda --adjacency_radius=-1 --clip_size=50 --detect_sign=1 --detect_threshold=3 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_907b89b3dd_rgoVH1
# Using tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_907b89b3dd_rgoVH1
# Preparing /mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_907b89b3dd_rgoVH1/timeseries.hdf5...
# Preparing neighborhood sorters...
#
# Detecting events on channel 2 (phase1)...
#
# Detecting events on channel 3 (phase1)...
#
# Detecting events on channel 1 (phase1)...
#
# Detecting events on channel 4 (phase1)...
#
# Computing PCA features for channel 3 (phase1)...
#
# Computing PCA features for channel 1 (phase1)...
# Computing PCA features for channel 2 (phase1)...
#
# Computing PCA features for channel 4 (phase1)...
#
# Clustering for channel 3 (phase1)...
#
# Clustering for channel 1 (phase1)...
#
# Found 1 clusters for channel 3 (phase1)...
# Computing templates for channel 3 (phase1)...
#
# Clustering for channel 4 (phase1)...
# Clustering for channel 2 (phase1)...
#
# Found 1 clusters for channel 1 (phase1)...
# Computing templates for channel 1 (phase1)...
#
# Found 1 clusters for channel 4 (phase1)...
# Computing templates for channel 4 (phase1)...
#
# Found 1 clusters for channel 2 (phase1)...
# Computing templates for channel 2 (phase1)...
#
# Re-assigning events for channel 3 (phase1)...
#
# Re-assigning events for channel 1 (phase1)...
#
# Re-assigning events for channel 4 (phase1)...
#
# Re-assigning events for channel 2 (phase1)...
#
# Computing PCA features for channel 2 (phase2)...
#
# Computing PCA features for channel 1 (phase2)...
#
# Computing PCA features for channel 4 (phase2)...
#
# Computing PCA features for channel 3 (phase2)...
#
# Clustering for channel 3 (phase2)...
#
# Found 1 clusters for channel 3 (phase2)...
#
# Clustering for channel 4 (phase2)...
# Clustering for channel 1 (phase2)...
#
# Clustering for channel 2 (phase2)...
#
# Found 1 clusters for channel 4 (phase2)...
#
# Found 1 clusters for channel 1 (phase2)...
#
# Found 1 clusters for channel 2 (phase2)...
#
# Preparing output...
#
# Writing firings file...
#
# Done.
#
# Elapsed time for processor ms4alg.sort: 28.021 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.cluster_metrics --inputs firings:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_firings.mda timeseries:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_pre.mda --parameters samplerate:48000 --outputs cluster_metrics_out:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_cbb31064fdf41dba5bef9a3b2f53a61933f244df.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Process ms3.cluster_metrics already completed. ]
# [ Creating output prv for cluster_metrics_out ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.isolation_metrics --inputs firings:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_firings.mda timeseries:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_pre.mda --parameters compute_bursting_parents:true --outputs metrics_out:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_db53ceef8b6625385c22aa2f05ab4b15747de3db.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Process ms3.isolation_metrics already completed. ]
# [ Creating output prv for metrics_out ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.combine_cluster_metrics --inputs metrics_list:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_cbb31064fdf41dba5bef9a3b2f53a61933f244df.prv metrics_list:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_db53ceef8b6625385c22aa2f05ab4b15747de3db.prv --parameters --outputs metrics_out:/mnt/e/Apollo_D_Drive/b6_august_18_2/temp_metrics.json
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# Locating /mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_cbb31064fdf41dba5bef9a3b2f53a61933f244df.prv ...
# Locating /mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_db53ceef8b6625385c22aa2f05ab4b15747de3db.prv ...
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/etc/mountainlab/packages/ms3.mp ms3.combine_cluster_metrics --metrics_list=/mnt/e/Apollo_D_Drive/MountainSortTempJs/output_f29e543826254be8de8c9ffe6c7ff1672ef057e7_cluster_metrics_out --metrics_list=/mnt/e/Apollo_D_Drive/MountainSortTempJs/output_5f474ef96e8ba7e6aad1aa5d861559f90d0cc38d_metrics_out --metrics_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_e72289e48a_fIcUHJ/output_metrics_out.json --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_e72289e48a_fIcUHJ
# Elapsed time for processor ms3.combine_cluster_metrics: 0.047 sec
# Finalizing output metrics_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process pyms.add_curation_tags --inputs metrics:/mnt/e/Apollo_D_Drive/b6_august_18_2/temp_metrics.json --parameters firing_rate_thresh:0.05 isolation_thresh:0.95 noise_overlap_thresh:0.03 peak_snr_thresh:1.5 --outputs metrics_tagged:/mnt/e/Apollo_D_Drive/b6_august_18_2/b6_august_18_2_simple_circle_180830_134604_T1_metrics.json
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/franklab_mstaggedcuration/python/tagged_curation.py pyms.add_curation_tags --metrics=/mnt/e/Apollo_D_Drive/b6_august_18_2/temp_metrics.json --metrics_tagged=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_d62cd94cf3_E9qKXt/output_metrics_tagged.json --firing_rate_thresh=0.05 --isolation_thresh=0.95 --noise_overlap_thresh=0.03 --peak_snr_thresh=1.5 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_d62cd94cf3_E9qKXt
# Elapsed time for processor pyms.add_curation_tags: 0.245 sec
# Finalizing output metrics_tagged
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# True
