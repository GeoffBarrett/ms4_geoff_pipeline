# %%
from p_ms4_geoff import sort_dataset
import os
import numpy as np

# %%
def find_sub(string, sub):
    '''finds all instances of a substring within a string and outputs a list of indices'''
    result = []
    k = 0
    while k < len(string):
        k = string.find(sub, k)
        if k == -1:
            return result
        else:
            result.append(k)
            k += 1  # change to k += len(sub) to not search overlapping results
    return result


def get_ubuntu_path(filepath):
    # get the drive letter

    drive_letter_i = filepath.find(':/')

    if drive_letter_i == -1:
        drive_letter_i = filepath.find(':\\')

    drive_letter = filepath[:drive_letter_i].lower()

    i = 1
    while drive_letter_i + i == '/':
        i += 1

    remaining_path = filepath[drive_letter_i + i + 1:]
    linux_path = '/mnt/%s/%s' % (drive_letter, remaining_path)
    
    # add single quotes so linux can understand the special characters
    if '(' in linux_path or ')' in linux_path:
        linux_path = "'%s'" % linux_path

    return os.path.normpath((linux_path)).replace('\\', '/')

# %% [markdown]
# ### Note I use get_ubuntu_path because I use the Windows Subsystem for Linux so I convert my windows paths to what they get mapped to in Linux. If you are on a Linux machine you can skip the get_ubunut_path parts.

# %%
raw_fname = 'E://Apollo_D_Drive//04032018//b6_march_18_1_180403_150327_T4_raw.mda'

mda_basename = os.path.splitext(raw_fname)[0]
mda_basename = mda_basename[:find_sub(mda_basename, '_')[-1]]

firings_out = mda_basename + '_firings.mda'
pre_out_fname = get_ubuntu_path(mda_basename + '_pre.mda')
metrics_out_fname = get_ubuntu_path(mda_basename + '_metrics.json')

raw_fname = get_ubuntu_path(raw_fname)

# %%
pre_out_fname = os.path.splitext(raw_fname)[0] + '_pre.mda'
filt_out_fname = os.path.splitext(raw_fname)[0] + '_filt.mda'
firings_out = os.path.splitext(raw_fname)[0] + '_firings.mda'
metrics_out_fname = os.path.splitext(raw_fname)[0] + '_metrics.json'
print(pre_out_fname, firings_out, metrics_out_fname)
# Out:
# /mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda /mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_firings.mda /mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_metrics.json

# %%
sort_dataset(raw_fname=raw_fname, filt_out_fname=filt_out_fname, pre_out_fname=pre_out_fname, metrics_out_fname=metrics_out_fname, firings_out=firings_out)
# Out:
# RUNNING: ml-run-process ephys.bandpass_filter --inputs timeseries:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw.mda --parameters freq_max:7000 freq_min:300 samplerate:30000 --outputs timeseries_out:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_filt.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.bandpass_filter --timeseries=/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw.mda --timeseries_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_7bf5fd2371_CquH0R/output_timeseries_out.mda --freq_max=7000 --freq_min=300 --samplerate=30000 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_7bf5fd2371_CquH0R
# Chunk size: 30000, Padding: 3000, Num chunks: 765, Num processes: 12
#
# Processed 238 of 765 chunks...
# Processed 585 of 765 chunks...
#
# Elapsed time for processor ephys.bandpass_filter: 10.584 sec
# Finalizing output timeseries_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ephys.whiten --inputs timeseries:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_filt.mda --parameters --outputs timeseries_out:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ephys/preprocessing/preprocessing.py.mp ephys.whiten --timeseries=/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_filt.mda --timeseries_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_ab307adb49_6B7il4/output_timeseries_out.mda --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_ab307adb49_6B7il4
# Chunk size: 300000, Num chunks: 77, Num processes: 12
#
# Elapsed time for processor ephys.whiten: 4.523 sec
# Finalizing output timeseries_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms4alg.sort --inputs timeseries:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda --parameters adjacency_radius:-1 clip_size:50 detect_sign:1 detect_threshold:3 --outputs firings_out:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_firings.mda
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/ml_ms4alg/ms4alg_spec.py.mp ms4alg.sort --timeseries=/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda --geom= --firings_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_504b0e332c_Akfu9P/output_firings_out.mda --adjacency_radius=-1 --clip_size=50 --detect_sign=1 --detect_threshold=3 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_504b0e332c_Akfu9P
# Using tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_504b0e332c_Akfu9P
# Preparing /mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_504b0e332c_Akfu9P/timeseries.hdf5...
# Preparing neighborhood sorters...
#
# Detecting events on channel 1 (phase1)...
#
# Detecting events on channel 2 (phase1)...
#
# Detecting events on channel 4 (phase1)...
#
# Detecting events on channel 3 (phase1)...
#
# Computing PCA features for channel 1 (phase1)...
#
# Computing PCA features for channel 3 (phase1)...
# Computing PCA features for channel 4 (phase1)...
#
# Computing PCA features for channel 2 (phase1)...
#
# Clustering for channel 3 (phase1)...
#
# Found 1 clusters for channel 3 (phase1)...
# Computing templates for channel 3 (phase1)...
#
# Clustering for channel 1 (phase1)...
#
# Clustering for channel 2 (phase1)...
#
# Found 1 clusters for channel 1 (phase1)...
# Computing templates for channel 1 (phase1)...
#
# Clustering for channel 4 (phase1)...
#
# Found 1 clusters for channel 2 (phase1)...
# Computing templates for channel 2 (phase1)...
#
# Found 1 clusters for channel 4 (phase1)...
# Computing templates for channel 4 (phase1)...
#
# Re-assigning events for channel 3 (phase1)...
#
# Re-assigning events for channel 1 (phase1)...
#
# Re-assigning events for channel 2 (phase1)...
#
# Re-assigning events for channel 4 (phase1)...
#
# Computing PCA features for channel 1 (phase2)...
#
# Computing PCA features for channel 2 (phase2)...
#
# Computing PCA features for channel 4 (phase2)...
#
# Computing PCA features for channel 3 (phase2)...
#
# Clustering for channel 3 (phase2)...
#
# Found 1 clusters for channel 3 (phase2)...
#
# Clustering for channel 1 (phase2)...
#
# Clustering for channel 2 (phase2)...
#
# Clustering for channel 4 (phase2)...
#
# Found 1 clusters for channel 1 (phase2)...
#
# Found 1 clusters for channel 2 (phase2)...
#
# Found 1 clusters for channel 4 (phase2)...
#
# Preparing output...
#
# Writing firings file...
#
# Done.
#
# Elapsed time for processor ms4alg.sort: 12.396 sec
# Finalizing output firings_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.cluster_metrics --inputs firings:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_firings.mda timeseries:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda --parameters samplerate:30000 --outputs cluster_metrics_out:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_d3b73e94872e327b09eca5b3d19defe5ca0e7333.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Process ms3.cluster_metrics already completed. ]
# [ Creating output prv for cluster_metrics_out ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.isolation_metrics --inputs firings:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_firings.mda timeseries:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_pre.mda --parameters compute_bursting_parents:true --outputs metrics_out:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_5623588eda6dca4a0dd90294a6ffd84b46a2e9c0.prv
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Process ms3.isolation_metrics already completed. ]
# [ Creating output prv for metrics_out ... ]
# [ Done. ]
# RUNNING: ml-run-process ms3.combine_cluster_metrics --inputs metrics_list:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_d3b73e94872e327b09eca5b3d19defe5ca0e7333.prv metrics_list:/mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_5623588eda6dca4a0dd90294a6ffd84b46a2e9c0.prv --parameters --outputs metrics_out:/mnt/e/Apollo_D_Drive/04032018/temp_metrics.json
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# Locating /mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_cluster_metrics_out_d3b73e94872e327b09eca5b3d19defe5ca0e7333.prv ...
# Locating /mnt/e/Apollo_D_Drive/MountainSortTempJs/mountainlab/tmp_short_term/output_metrics_out_5623588eda6dca4a0dd90294a6ffd84b46a2e9c0.prv ...
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/etc/mountainlab/packages/ms3.mp ms3.combine_cluster_metrics --metrics_list=/mnt/e/Apollo_D_Drive/MountainSortTempJs/output_9876768e85fb6ba6daf3415b745eef952eaae180_cluster_metrics_out --metrics_list=/mnt/e/Apollo_D_Drive/MountainSortTempJs/output_6c2947644ff9cc6f54e167a5a1cf516861ac808d_metrics_out --metrics_out=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_44009d62f9_mTyZIj/output_metrics_out.json --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_44009d62f9_mTyZIj
# Elapsed time for processor ms3.combine_cluster_metrics: 0.058 sec
# Finalizing output metrics_out
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# RUNNING: ml-run-process pyms.add_curation_tags --inputs metrics:/mnt/e/Apollo_D_Drive/04032018/temp_metrics.json --parameters firing_rate_thresh:0.05 isolation_thresh:0.95 noise_overlap_thresh:0.03 peak_snr_thresh:1.5 --outputs metrics_tagged:/mnt/e/Apollo_D_Drive/04032018/b6_march_18_1_180403_150327_T4_raw_metrics.json
# [ Getting processor spec... ]
# [ Checking inputs and substituting prvs ... ]
# [ Computing process signature ... ]
# [ Checking outputs... ]
# [ Checking process cache ... ]
# [ Creating temporary directory ... ]
# [ Preparing temporary outputs... ]
# [ Initializing process ... ]
# [ Running ... ] /root/conda/envs/mlab/bin/python3 /root/conda/envs/mlab/etc/mountainlab/packages/franklab_mstaggedcuration/python/tagged_curation.py pyms.add_curation_tags --metrics=/mnt/e/Apollo_D_Drive/04032018/temp_metrics.json --metrics_tagged=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_3364f92a9c_IcMHeo/output_metrics_tagged.json --firing_rate_thresh=0.05 --isolation_thresh=0.95 --noise_overlap_thresh=0.03 --peak_snr_thresh=1.5 --_tempdir=/mnt/e/Apollo_D_Drive/MountainSortTempJs/tempdir_3364f92a9c_IcMHeo
# Elapsed time for processor pyms.add_curation_tags: 0.221 sec
# Finalizing output metrics_tagged
# [ Saving to process cache ... ]
# [ Removing temporary directory ... ]
# [ Done. ]
# True
